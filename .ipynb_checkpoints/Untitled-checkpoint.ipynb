# %%
print("yo")
# Out:
# yo

# %%
#so cool
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hey
#
# NameError: name 'hey' is not defined
